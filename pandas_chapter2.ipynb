# %%
import pandas as pd

# %%
df=pd.read_csv("Summary of Weather.csv",low_memory=False)#since memory is large

# %%
df
# Out:
#           STA        Date  Precip  WindGustSpd    MaxTemp    MinTemp   MeanTemp Snowfall PoorWeather  YR  MO  DA  PRCP  DR  SPD   MAX   MIN   MEA SNF  SND  FT  FB  FTI  ITH  PGT TSHDSBRSGF  SD3  RHX  RHN  RVG  WTE
# 0       10001    1942-7-1   1.016          NaN  25.555556  22.222222  23.888889        0         NaN  42   7   1  0.04 NaN  NaN  78.0  72.0  75.0   0  NaN NaN NaN  NaN  NaN  NaN        NaN  NaN  NaN  NaN  NaN  NaN
# 1       10001    1942-7-2       0          NaN  28.888889  21.666667  25.555556        0         NaN  42   7   2     0 NaN  NaN  84.0  71.0  78.0   0  NaN NaN NaN  NaN  NaN  NaN        NaN  NaN  NaN  NaN  NaN  NaN
# 2       10001    1942-7-3    2.54          NaN  26.111111  22.222222  24.444444        0         NaN  42   7   3   0.1 NaN  NaN  79.0  72.0  76.0   0  NaN NaN NaN  NaN  NaN  NaN        NaN  NaN  NaN  NaN  NaN  NaN
# ...

# %%
df[:5]#to get first 5 rows of dataframe
# Out:
#      STA      Date Precip  WindGustSpd    MaxTemp    MinTemp   MeanTemp Snowfall PoorWeather  YR  MO  DA  PRCP  DR  SPD   MAX   MIN   MEA SNF  SND  FT  FB  FTI  ITH  PGT TSHDSBRSGF  SD3  RHX  RHN  RVG  WTE
# 0  10001  1942-7-1  1.016          NaN  25.555556  22.222222  23.888889        0         NaN  42   7   1  0.04 NaN  NaN  78.0  72.0  75.0   0  NaN NaN NaN  NaN  NaN  NaN        NaN  NaN  NaN  NaN  NaN  NaN
# 1  10001  1942-7-2      0          NaN  28.888889  21.666667  25.555556        0         NaN  42   7   2     0 NaN  NaN  84.0  71.0  78.0   0  NaN NaN NaN  NaN  NaN  NaN        NaN  NaN  NaN  NaN  NaN  NaN
# 2  10001  1942-7-3   2.54          NaN  26.111111  22.222222  24.444444        0         NaN  42   7   3   0.1 NaN  NaN  79.0  72.0  76.0   0  NaN NaN NaN  NaN  NaN  NaN        NaN  NaN  NaN  NaN  NaN  NaN
# ...

# %%
df['MaxTemp'][:5]#for accesing each colums
# Out:
# 0    25.555556
# 1    28.888889
# 2    26.111111
# 3    26.666667
# 4    26.666667
# Name: MaxTemp, dtype: float64

# %%
df[:5]['MaxTemp']#direction does'nt matter
# Out:
# 0    25.555556
# 1    28.888889
# 2    26.111111
# 3    26.666667
# 4    26.666667
# Name: MaxTemp, dtype: float64

# %% [markdown]
# # selecting multiple colums

# %%
df[['MaxTemp','MinTemp','MeanTemp']][:5]
# Out:
#      MaxTemp    MinTemp   MeanTemp
# 0  25.555556  22.222222  23.888889
# 1  28.888889  21.666667  25.555556
# 2  26.111111  22.222222  24.444444
# 3  26.666667  22.222222  24.444444
# 4  26.666667  21.666667  24.444444

# %%
df['MeanTemp'].value_counts()
# Out:
#  26.666667    14835
#  25.555556    11152
#  27.777778    11089
#  24.444444     6762
#  27.222222     5122
#  26.111111     5043
#  23.333333     4797
#  28.888889     4679
#  22.222222     3461
#  25.000000     3327
#  21.111111     3071
#  28.333333     2751
#  20.000000     2418
#  23.888889     2276
#  18.888889     1912
#  30.000000     1727
#  17.777778     1697
#  16.666667     1581
#  22.777778     1537
#  15.555556     1405
#  21.666667     1235
#  20.555556     1151
#  14.444444     1144
#  29.444444     1106
#  12.222222     1090
#  13.333333     1070
#  11.111111     1012
#  10.000000     1005
#  31.111111      916
#  8.888889       853
#               ...
# -13.888889       14
# -24.444444       14
# -17.222222       12
#  38.333333       12
# -27.777778       12
# -25.555556        9
# -21.666667        9
# -26.666667        8
# -25.000000        8
# -30.000000        7
# -19.444444        7
# -31.111111        7
# -22.777778        6
# -20.555556        5
# ...

# %%
df_count=df['MeanTemp'].value_counts()

# %%
df_count[:5]
# Out:
#  26.666667    14835
#  25.555556    11152
#  27.777778    11089
#  24.444444     6762
#  27.222222     5122
#  26.111111     5043
#  23.333333     4797
#  28.888889     4679
#  22.222222     3461
#  25.000000     3327
#  21.111111     3071
#  28.333333     2751
#  20.000000     2418
#  23.888889     2276
#  18.888889     1912
#  30.000000     1727
#  17.777778     1697
#  16.666667     1581
#  22.777778     1537
#  15.555556     1405
#  21.666667     1235
#  20.555556     1151
#  14.444444     1144
#  29.444444     1106
#  12.222222     1090
#  13.333333     1070
#  11.111111     1012
#  10.000000     1005
#  31.111111      916
#  8.888889       853
#               ...
#  7.777778       713
#  18.333333      710
#  6.666667       687
#  32.222222      685
#  17.222222      648
#  5.555556       621
#  16.111111      610
#  15.000000      537
# -17.777778      531
#  33.333333      512
#  30.555556      498
#  4.444444       481
#  12.777778      454
#  13.888889      450
# ...

# %%
df_count[:10].plot(kind='bar')#graph of first 10 mean
# Out:
# /home/fractaluser/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
