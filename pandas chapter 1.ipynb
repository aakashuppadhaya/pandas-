# %% [markdown]
# # reading data from csv file

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("startup_funding.csv")

# %%
df#printing dataframe
# Out:
#        SNo         Date       StartupName   IndustryVertical  \
# 0        0   01/08/2017          TouchKin         Technology
# 1        1   02/08/2017           Ethinos         Technology
# 2        2   02/08/2017      Leverage Edu  Consumer Internet
# 3        3   02/08/2017              Zepo  Consumer Internet
# 4        4   02/08/2017      Click2Clinic  Consumer Internet
# 5        5   01/07/2017     Billion Loans  Consumer Internet
# 6        6   03/07/2017  Ecolibriumenergy         Technology
# 7        7   04/07/2017             Droom          eCommerce
# 8        8   05/07/2017         Jumbotail          eCommerce
# 9        9   05/07/2017            Moglix          eCommerce
# 10      10   05/07/2017        Timesaverz  Consumer Internet
# 11      11   06/07/2017            Minjar         Technology
# 12      12   06/07/2017       MyCity4kids  Consumer Internet
# 13      13   07/07/2017          Clip App  Consumer Internet
# ...

# %%
#looking at the first three rows of dataset
df[:3]
# Out:
#    SNo        Date   StartupName   IndustryVertical  \
# 0    0  01/08/2017      TouchKin         Technology
# 1    1  02/08/2017       Ethinos         Technology
# 2    2  02/08/2017  Leverage Edu  Consumer Internet
#
#                                      SubVertical CityLocation  \
# 0                       Predictive Care Platform    Bangalore
# 1                       Digital Marketing Agency       Mumbai
# 2  Online platform for Higher Education Services    New Delhi
#
#                                        InvestorsName  InvestmentType  \
# 0                                        Kae Capital  Private Equity
# 1                         Triton Investment Advisors  Private Equity
# 2  Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...    Seed Funding
#
#   AmountInUSD Remarks
# 0   1,300,000     NaN
# 1         NaN     NaN
# 2         NaN     NaN

# %% [markdown]
# # selecting the colums

# %%
df["Date"]
# Out:
# 0        01/08/2017
# 1        02/08/2017
# 2        02/08/2017
# 3        02/08/2017
# 4        02/08/2017
# 5        01/07/2017
# 6        03/07/2017
# 7        04/07/2017
# 8        05/07/2017
# 9        05/07/2017
# 10       05/07/2017
# 11       06/07/2017
# 12       06/07/2017
# 13       07/07/2017
# 14       07/07/2017
# 15       10/07/2017
# 16       11/07/2017
# 17       11/07/2017
# 18       11/07/2017
# 19       12/07/2017
# 20       12/07/2017
# 21       12/07/2017
# 22       12/07/2017
# 23       14/07/2017
# 24       14/07/2017
# 25       17/07/2017
# 26       17/07/2017
# 27       18/07/2017
# 28       18/07/2017
# 29       18/07/2017
#            ...
# 2342     19/01/2015
# 2343     19/01/2015
# 2344     19/01/2015
# 2345     19/01/2015
# 2346     19/01/2015
# 2347     19/01/2015
# 2348     19/01/2015
# 2349     19/01/2015
# 2350     20/01/2015
# 2351     20/01/2015
# 2352     20/01/2015
# 2353     21/01/2015
# 2354     21/01/2015
# 2355     21/05/2015
# ...

# %%
#df['SNo','IndustryVertical'].plot()
plt.show()
df.head()#for printing first 5 values of dataset
# Out:
#    SNo        Date   StartupName   IndustryVertical  \
# 0    0  01/08/2017      TouchKin         Technology
# 1    1  02/08/2017       Ethinos         Technology
# 2    2  02/08/2017  Leverage Edu  Consumer Internet
# 3    3  02/08/2017          Zepo  Consumer Internet
# 4    4  02/08/2017  Click2Clinic  Consumer Internet
#
#                                      SubVertical CityLocation  \
# 0                       Predictive Care Platform    Bangalore
# 1                       Digital Marketing Agency       Mumbai
# 2  Online platform for Higher Education Services    New Delhi
# 3                         DIY Ecommerce platform       Mumbai
# 4                  healthcare service aggregator    Hyderabad
#
#                                        InvestorsName  InvestmentType  \
# 0                                        Kae Capital  Private Equity
# 1                         Triton Investment Advisors  Private Equity
# ...

# %%
df.plot(figsize=(5,5))
#plt.show()
# Out:
# /home/fractaluser/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
pd.set_option('display.mpl_style', 'default')
# Out:
# /home/fractaluser/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2881: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.plot(figsize=(15, 10))
# Out:
# /home/fractaluser/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
ax = df.plot(kind='bar', title ="V comp",figsize=(15,10),legend=True, fontsize=12)
# Out:
# /home/fractaluser/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
ax = df.plot(kind='bar', title ="V comp",figsize=(15,10),legend=True, fontsize=12)
ax.set_xlabel("StartupName", fontsize=12)
ax.set_ylabel("AmountInUSD", fontsize=12)
plt.show()
# Out:
# /home/fractaluser/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
df.head()//first 5 elemt
# Out:
#    SNo        Date   StartupName   IndustryVertical  \
# 0    0  01/08/2017      TouchKin         Technology
# 1    1  02/08/2017       Ethinos         Technology
# 2    2  02/08/2017  Leverage Edu  Consumer Internet
# 3    3  02/08/2017          Zepo  Consumer Internet
# 4    4  02/08/2017  Click2Clinic  Consumer Internet
#
#                                      SubVertical CityLocation  \
# 0                       Predictive Care Platform    Bangalore
# 1                       Digital Marketing Agency       Mumbai
# 2  Online platform for Higher Education Services    New Delhi
# 3                         DIY Ecommerce platform       Mumbai
# 4                  healthcare service aggregator    Hyderabad
#
#                                        InvestorsName  InvestmentType  \
# 0                                        Kae Capital  Private Equity
# 1                         Triton Investment Advisors  Private Equity
# ...

# %%
df = pd.read_csv('startup_funding.csv', sep=';', encoding='latin1', parse_dates=['StartupName'], dayfirst=True, index_col='Date')
df['SNo'].plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-23eadd33e531> in <module>()
# ----> 1 df = pd.read_csv('startup_funding.csv', sep=';', encoding='latin1', parse_dates=['StartupName'], dayfirst=True, index_col='Date')
#       2 df['SNo'].plot()
#
# ...
